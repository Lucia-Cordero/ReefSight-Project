# %% [markdown]
# # Get data

# %%
import zipfile
import os
import random
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Coral_Reef_Global_Bleaching

# Define the path to the new dataset
path = '/Users/et/code/eliastopfstedt/ReefSight-Project/data/Coral_Reef_Global_Bleaching/'

# Path to the zip file
zip_file_path = os.path.join(path, 'archive.zip')

# Extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(path)

# Define the paths to the extracted CSV files
coral_csv_path = os.path.join(path, 'archive/coral.csv')
coral_whole_csv_path = os.path.join(path, 'archive/coral_whole.csv')

# Load the CSV files into separate pandas DataFrames
coral_df = pd.read_csv(coral_csv_path)
coral_whole_df = pd.read_csv(coral_whole_csv_path)

# Display the first few rows of each DataFrame
print("Coral DataFrame:")
print(coral_df.head())

print("\nCoral Whole DataFrame:")
print(coral_whole_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 18
#      15 coral_whole_csv_path = os.path.join(path, 'archive/coral_whole.csv')
#      17 # Load the CSV files into separate pandas DataFrames
# ---> 18 coral_df = pd.read_csv(coral_csv_path)
#      19 coral_whole_df = pd.read_csv(coral_whole_csv_path)
#      21 # Display the first few rows of each DataFrame
#
# NameError: name 'pd' is not defined
