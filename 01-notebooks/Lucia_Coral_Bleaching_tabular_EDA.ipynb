# %% [markdown]
# # Environmental Reef Tabular Dataset

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exploratory Dataset Analysis : General

# %% [markdown]
# ### Loading the DF

# %%
df = pd.read_csv("/home/lucia/code/Lucia-Cordero/08-ReefSight-Project/01-Raw-data/global_bleaching_environmental.csv", low_memory=False)
df
# Out:
#        Site_ID  Sample_ID Data_Source  Latitude_Degrees  Longitude_Degrees  \
# 0         2501   10324336      Donner           23.1630           -82.5260
# 1         3467   10324754      Donner          -17.5750          -149.7833
# 2         1794   10323866      Donner           18.3690           -64.5640
# 3         8647   10328028      Donner           17.7600           -64.5680
# 4         8648   10328029      Donner           17.7690           -64.5830
# ...        ...        ...         ...               ...                ...
# 41356    15446   10310562  Reef_Check           -8.3651           116.0844
# 41357    15456   10310527  Reef_Check           -8.3473           116.0503
# 41358    15456   10310527  Reef_Check           -8.3473           116.0503
# 41359    15457   10310536  Reef_Check           -8.3445           116.0629
# 41360    15457   10310536  Reef_Check           -8.3445           116.0629
#
#       Ocean_Name                     Reef_ID            Realm_Name  \
# 0       Atlantic                          nd     Tropical Atlantic
# 1        Pacific                          nd  Eastern Indo-Pacific
# 2       Atlantic                          nd     Tropical Atlantic
# 3       Atlantic                          nd     Tropical Atlantic
# 4       Atlantic                          nd     Tropical Atlantic
# ...          ...                         ...                   ...
# 41356    Pacific       116.5.3.9E.8.21.54.4S  Central Indo-Pacific
# 41357    Pacific       116.3.1.1E.8.20.50.2S  Central Indo-Pacific
# 41358    Pacific       116.3.1.1E.8.20.50.2S  Central Indo-Pacific
# 41359    Pacific  116.3.46.548E.8.20.40.236S  Central Indo-Pacific
# 41360    Pacific  116.3.46.548E.8.20.40.236S  Central Indo-Pacific
#
#                                    Ecoregion_Name      Country_Name  ...  \
# 0                         Cuba and Cayman Islands              Cuba  ...
# 1                Society Islands French Polynesia  French Polynesia  ...
# 2      Hispaniola Puerto Rico and Lesser Antilles    United Kingdom  ...
# 3      Hispaniola Puerto Rico and Lesser Antilles     United States  ...
# 4      Hispaniola Puerto Rico and Lesser Antilles     United States  ...
# ...                                           ...               ...  ...
# 41356           Lesser Sunda Islands and Savu Sea         Indonesia  ...
# 41357           Lesser Sunda Islands and Savu Sea         Indonesia  ...
# 41358           Lesser Sunda Islands and Savu Sea         Indonesia  ...
# 41359           Lesser Sunda Islands and Savu Sea         Indonesia  ...
# 41360           Lesser Sunda Islands and Savu Sea         Indonesia  ...
#
#       TSA_FrequencyMax TSA_FrequencyMean TSA_DHW TSA_DHW_Standard_Deviation  \
# 0                    5                 0       0                       0.74
# 1                    4                 0    0.26                       0.67
# 2                    7                 0       0                       1.04
# 3                    4                 0       0                       0.75
# 4                    5                 0       0                       0.92
# ...                ...               ...     ...                        ...
# 41356                8                 1    2.09                       1.49
# 41357                8                 1       2                       1.29
# 41358                8                 1       2                       1.29
# 41359                8                 1       2                       1.29
# 41360                8                 1       2                       1.29
#
#       TSA_DHWMax TSA_DHWMean        Date  \
# 0           7.25        0.18  2005-09-15
# 1           4.65        0.19  1991-03-15
# 2          11.66        0.26  2006-01-15
# 3           5.64         0.2  2006-04-15
# 4           6.89        0.25  2006-04-15
# ...          ...         ...         ...
# 41356          9        0.63  2019-05-28
# 41357       8.01        0.65  2019-05-16
# 41358       8.01        0.65  2019-05-16
# 41359       8.01        0.65  2019-05-29
# 41360       8.01        0.65  2019-05-29
#
#                                            Site_Comments  \
# 0                                                     nd
# 1      The bleaching does not  appear to have gained ...
# 2                                                     nd
# 3                                                     nd
# 4                                                     nd
# ...                                                  ...
# 41356                                                 nd
# 41357                                                 nd
# 41358                                                 nd
# 41359                                                 nd
# 41360                                                 nd
#
#                                          Sample_Comments  Bleaching_Comments
# 0                                                     nd                  nd
# 1      The bleaching does not  appear to have gained ...                  nd
# 2                                                     nd                  nd
# 3                                                     nd                  nd
# 4                                                     nd                  nd
# ...                                                  ...                 ...
# 41356                                                 nd                  nd
# 41357                                                 nd                  nd
# 41358                                                 nd                  nd
# 41359                                                 nd                  nd
# 41360                                                 nd                  nd
#
# [41361 rows x 62 columns]

# %% [markdown]
# ### DF essentials: shape, description, column names

# %%
df.shape
# Out:
# (41361, 62)

# %% [markdown]
# <font color='green'>**Conclusion:** The dataframe is made of 41k rows, 62 columns </font>

# %%
df.columns
# Out:
# Index(['Site_ID', 'Sample_ID', 'Data_Source', 'Latitude_Degrees',
#        'Longitude_Degrees', 'Ocean_Name', 'Reef_ID', 'Realm_Name',
#        'Ecoregion_Name', 'Country_Name', 'State_Island_Province_Name',
#        'City_Town_Name', 'Site_Name', 'Distance_to_Shore', 'Exposure',
#        'Turbidity', 'Cyclone_Frequency', 'Date_Day', 'Date_Month', 'Date_Year',
#        'Depth_m', 'Substrate_Name', 'Percent_Cover', 'Bleaching_Level',
#        'Percent_Bleaching', 'ClimSST', 'Temperature_Kelvin',
#        'Temperature_Mean', 'Temperature_Minimum', 'Temperature_Maximum',
#        'Temperature_Kelvin_Standard_Deviation', 'Windspeed', 'SSTA',
#        'SSTA_Standard_Deviation', 'SSTA_Mean', 'SSTA_Minimum', 'SSTA_Maximum',
#        'SSTA_Frequency', 'SSTA_Frequency_Standard_Deviation',
#        'SSTA_FrequencyMax', 'SSTA_FrequencyMean', 'SSTA_DHW',
#        'SSTA_DHW_Standard_Deviation', 'SSTA_DHWMax', 'SSTA_DHWMean', 'TSA',
#        'TSA_Standard_Deviation', 'TSA_Minimum', 'TSA_Maximum', 'TSA_Mean',
#        'TSA_Frequency', 'TSA_Frequency_Standard_Deviation', 'TSA_FrequencyMax',
#        'TSA_FrequencyMean', 'TSA_DHW', 'TSA_DHW_Standard_Deviation',
#        'TSA_DHWMax', 'TSA_DHWMean', 'Date', 'Site_Comments', 'Sample_Comments',
#        'Bleaching_Comments'],
#       dtype='object')

# %% [markdown]
# Percent of null values in the DF

# %%
df.isnull().sum().sum() / df.size * 100
# Out:
# 0.0

# %%
null_summary = pd.DataFrame({
    "null_count": df.isna().sum(),
    "null_percent": df.isna().mean() * 100
})

null_summary.sort_values("null_percent", ascending=False)
# Out:
#                          null_count  null_percent
# Site_ID                           0           0.0
# TSA_Standard_Deviation            0           0.0
# SSTA_Standard_Deviation           0           0.0
# SSTA_Mean                         0           0.0
# SSTA_Minimum                      0           0.0
# ...                             ...           ...
# ClimSST                           0           0.0
# Temperature_Kelvin                0           0.0
# Temperature_Mean                  0           0.0
# Temperature_Minimum               0           0.0
# Bleaching_Comments                0           0.0
#
# [62 rows x 2 columns]

# %% [markdown]
# <font color='green'>**Conclusion:** 20% of null values in the whole DF;  16% in the percent bleaching column! </font>

# %% [markdown]
# ### Displaying selected columns of the DF

# %%
columns_to_show = ["Site_ID", "Date", "Ocean_Name", "Ecoregion_Name", "Country_Name","Distance_to_Shore", "Depth_m", "Exposure",
       "Turbidity", "Temperature_Kelvin", "Percent_Bleaching"]
df_chosen_cols = df[columns_to_show]
df_chosen_cols
# Out:
#        Site_ID        Date Ocean_Name  \
# 0         2501  2005-09-15   Atlantic
# 1         3467  1991-03-15    Pacific
# 2         1794  2006-01-15   Atlantic
# 3         8647  2006-04-15   Atlantic
# 4         8648  2006-04-15   Atlantic
# ...        ...         ...        ...
# 41356    15446  2019-05-28    Pacific
# 41357    15456  2019-05-16    Pacific
# 41358    15456  2019-05-16    Pacific
# 41359    15457  2019-05-29    Pacific
# 41360    15457  2019-05-29    Pacific
#
#                                    Ecoregion_Name      Country_Name  \
# 0                         Cuba and Cayman Islands              Cuba
# 1                Society Islands French Polynesia  French Polynesia
# 2      Hispaniola Puerto Rico and Lesser Antilles    United Kingdom
# 3      Hispaniola Puerto Rico and Lesser Antilles     United States
# 4      Hispaniola Puerto Rico and Lesser Antilles     United States
# ...                                           ...               ...
# 41356           Lesser Sunda Islands and Savu Sea         Indonesia
# 41357           Lesser Sunda Islands and Savu Sea         Indonesia
# 41358           Lesser Sunda Islands and Savu Sea         Indonesia
# 41359           Lesser Sunda Islands and Savu Sea         Indonesia
# 41360           Lesser Sunda Islands and Savu Sea         Indonesia
#
#       Distance_to_Shore Depth_m   Exposure Turbidity Temperature_Kelvin  \
# 0               8519.23      10    Exposed    0.0287             302.05
# 1               1431.62      14    Exposed    0.0262             303.30
# 2                182.33       7    Exposed    0.0429             299.18
# 3                313.13    9.02    Exposed    0.0424             299.61
# 4                   792   12.50    Exposed    0.0424              299.7
# ...                 ...     ...        ...       ...                ...
# 41356             91.31     5.6  Sheltered    0.0372             301.85
# 41357            129.08     3.5  Sheltered    0.0849             302.51
# 41358            129.08     3.5  Sheltered    0.0849             302.51
# 41359            209.17     7.8  Sheltered    0.0849             301.07
# 41360            209.17     7.8  Sheltered    0.0849             301.07
#
#       Percent_Bleaching
# 0                  50.2
# 1                  50.7
# 2                  50.9
# 3                  50.9
# 4                  50.9
# ...                 ...
# 41356                nd
# 41357                nd
# 41358                nd
# 41359                nd
# 41360                nd
#
# [41361 rows x 11 columns]

# %% [markdown]
# ### Distribution of y: 'Percent Bleaching'

# %%
df["Percent_Bleaching"] = pd.to_numeric(
    df["Percent_Bleaching"],
    errors="coerce"
)

# %%
df["Percent_Bleaching"].value_counts()
# Out:
# Percent_Bleaching
# 0.00     16629
# 5.50      1184
# 75.00      914
# 0.25       882
# 1.00       705
#          ...
# 6.13         1
# 6.11         1
# 6.09         1
# 5.98         1
# 97.22        1
# Name: count, Length: 2240, dtype: int64

# %%
df["Percent_Bleaching"].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sites_healthy = df[df["Percent_Bleaching"] == 0]
sites_healthy
# Out:
#        Site_ID  Sample_ID Data_Source  Latitude_Degrees  Longitude_Degrees  \
# 1860      4608       9625     Kumagai           24.4571           124.0986
# 1861      4615       9632     Kumagai           24.7998           125.1786
# 1862      4618       9635     Kumagai           26.2476           127.6682
# 1863      4621       9638     Kumagai           26.2752           127.7141
# 1864      4623       9640     Kumagai           26.4435           127.7727
# ...        ...        ...         ...               ...                ...
# 23255     1473   10320954  Reef_Check           16.0952           -88.2917
# 23256     3726   10320561  Reef_Check           15.9538           -86.4736
# 23257     3726   10320561  Reef_Check           15.9538           -86.4736
# 23258     5726   10310781  Reef_Check            6.5139           117.9243
# 23259     5726   10310781  Reef_Check            6.5139           117.9243
#
#       Ocean_Name                Reef_ID            Realm_Name  \
# 1860     Pacific                     nd  Central Indo-Pacific
# 1861     Pacific                     nd  Central Indo-Pacific
# 1862     Pacific                     nd  Central Indo-Pacific
# 1863     Pacific                     nd  Central Indo-Pacific
# 1864     Pacific                     nd  Central Indo-Pacific
# ...          ...                    ...                   ...
# 23255   Atlantic   88.17.504W.16.5.714N     Tropical Atlantic
# 23256   Atlantic  86.28.419W.15.57.230N     Tropical Atlantic
# 23257   Atlantic  86.28.419W.15.57.230N     Tropical Atlantic
# 23258    Pacific  117.55.459E.6.30.834N  Central Indo-Pacific
# 23259    Pacific  117.55.459E.6.30.834N  Central Indo-Pacific
#
#                    Ecoregion_Name Country_Name  ... TSA_FrequencyMax  \
# 1860   South Ryukyu Islands Japan        Japan  ...                6
# 1861   South Ryukyu Islands Japan        Japan  ...             7.75
# 1862   North Ryukyu Islands Japan        Japan  ...                7
# 1863   North Ryukyu Islands Japan        Japan  ...                8
# 1864   North Ryukyu Islands Japan        Japan  ...                9
# ...                           ...          ...  ...              ...
# 23255   Belize and west Caribbean       Belize  ...               10
# 23256   Belize and west Caribbean     Honduras  ...                9
# 23257   Belize and west Caribbean     Honduras  ...                9
# 23258                    Sulu Sea     Malaysia  ...               11
# 23259                    Sulu Sea     Malaysia  ...               11
#
#       TSA_FrequencyMean TSA_DHW TSA_DHW_Standard_Deviation TSA_DHWMax  \
# 1860                  1       0                       1.44       8.23
# 1861                  1       0                       1.27      10.08
# 1862                  0       0                        1.3      10.39
# 1863               0.67       0                       1.51      13.06
# 1864                  0       0                       1.31       13.2
# ...                 ...     ...                        ...        ...
# 23255                 2       0                       1.81      13.04
# 23256                 1       0                       1.65      10.43
# 23257                 1       0                       1.65      10.43
# 23258                 2    2.73                       1.55       9.52
# 23259                 2    2.73                       1.55       9.52
#
#       TSA_DHWMean        Date  Site_Comments  Sample_Comments  \
# 1860         0.52  2010-06-29             nd               nd
# 1861         0.41  2010-06-02             nd               nd
# 1862         0.37  2009-08-23             nd               nd
# 1863         0.42  2009-07-18             nd               nd
# 1864         0.39  2010-08-21             nd               nd
# ...           ...         ...            ...              ...
# 23255        0.83  2009-05-07             nd               nd
# 23256        0.65  2009-03-12             nd               nd
# 23257        0.65  2009-03-12             nd               nd
# 23258        0.81  2019-10-16             nd               nd
# 23259        0.81  2019-10-16             nd               nd
#
#        Bleaching_Comments
# 1860                   nd
# 1861                   nd
# 1862                   nd
# 1863                   nd
# 1864                   nd
# ...                   ...
# 23255                  nd
# 23256                  nd
# 23257                  nd
# 23258                  nd
# 23259                  nd
#
# [16629 rows x 62 columns]

# %%
len(sites_healthy)/len(df)*100
# Out:
# 40.20454050917531

# %% [markdown]
# <font color='green'>**Conclusion:** 40% of reefs are healthy (0% bleaching)</font>

# %% [markdown]
# ### Exploring multi-year data

# %% [markdown]
# Converting column to datetime + extract year

# %%
df["Date"] = pd.to_datetime(df["Date"])
df["Year"] = df["Date"].dt.year

# %%
sites_multi_year = (
    df.groupby("Site_ID")["Year"]
      .nunique()
      .reset_index()
)

sites_multi_year = sites_multi_year[sites_multi_year["Year"] > 1]

sites_multi_year
# Out:
#        Site_ID  Year
# 1            2     7
# 3            4     7
# 5            6     4
# 6            7     2
# 7            8     4
# ...        ...   ...
# 12597   999940     2
# 12610   999953     2
# 12641   999986     2
# 12657  1000003     2
# 12658  1000004     2
#
# [2086 rows x 2 columns]

# %% [markdown]
# Filter original DF to multi-year sites

# %% [markdown]
# <font color='green'>**Conclusion:** 2086 sites are multi-year sites</font>

# %%
multi_year_site_ids = sites_multi_year["Site_ID"]

df_multi_year_only = df[df["Site_ID"].isin(multi_year_site_ids)]

# %%
sites_multi_year["Year"].value_counts().sort_index().plot(kind='bar')
plt.title("Multi-year reef sites")
plt.ylabel("Number of years with records per site")
plt.xlabel("Number of reef sites")
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)  

plt.show()

# %% [markdown]
# <font color='green'>**Conclusion:** Majority of multi-year sites (~50%) only have observations for 2 years</font>

# %% [markdown]
# ## Exploratory Dataset Analysis : Great Barrier Reef

# %%
df_filtered_gbr = df_chosen_cols[
    (df_chosen_cols["Country_Name"] == "Australia") &
    (df_chosen_cols["Ecoregion_Name"].str.contains("Great Barrier Reef", case=False, na=False))
]
df_filtered_gbr
# Out:
#        Site_ID        Date Ocean_Name  \
# 9          499  1998-03-15    Pacific
# 42         886  1998-04-15    Pacific
# 61         121  1998-03-15    Pacific
# 227        500  1998-03-15    Pacific
# 291         29  2002-01-15    Pacific
# ...        ...         ...        ...
# 35360     1074  2007-07-15    Pacific
# 35361     1074  2007-07-15    Pacific
# 35362     1164  2007-12-15    Pacific
# 41343     9795  1998-03-15    Pacific
# 41344     9795  2002-02-15    Pacific
#
#                                 Ecoregion_Name Country_Name Distance_to_Shore  \
# 9      Central and northern Great Barrier Reef    Australia           2750.37
# 42     Central and northern Great Barrier Reef    Australia           1608.47
# 61     Central and northern Great Barrier Reef    Australia            275.04
# 227    Central and northern Great Barrier Reef    Australia            163.79
# 291                Southern Great Barrier Reef    Australia            989.12
# ...                                        ...          ...               ...
# 35360  Central and northern Great Barrier Reef    Australia            809.41
# 35361  Central and northern Great Barrier Reef    Australia            809.41
# 35362              Southern Great Barrier Reef    Australia           8406.82
# 41343  Central and northern Great Barrier Reef    Australia             21.14
# 41344  Central and northern Great Barrier Reef    Australia             21.14
#
#       Depth_m   Exposure Turbidity Temperature_Kelvin Percent_Bleaching
# 9          nd  Sheltered    0.2197             302.41             51.53
# 42         nd  Sheltered      0.07             300.77             53.35
# 61          5  Sheltered    0.1919             302.37                55
# 227        nd    Exposed    0.0661             301.49             62.05
# 291       5.5  Sheltered    0.0731             300.94                65
# ...       ...        ...       ...                ...               ...
# 35360       5  Sheltered    0.2173             294.39                nd
# 35361       5  Sheltered    0.2173             294.39                nd
# 35362      nd    Exposed    0.0746                 nd                nd
# 41343     2.6  Sheltered    0.0822                 nd                nd
# 41344     2.6  Sheltered    0.0822             302.11                nd
#
# [2105 rows x 11 columns]

# %% [markdown]
# <font color='green'>**Conclusion:** 2K entries for the Great Barrier Reef </font>
