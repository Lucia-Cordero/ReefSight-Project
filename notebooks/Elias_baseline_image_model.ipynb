# %% [markdown]
# # Define paths

# %%
# To run this model notebook, first run Elias_create_train_val_test_datasets.ipynb to create the datasets, then copy the printed paths and paste them below

train_data_dir = '/Users/et/code/Lucia-Cordero/ReefSight-Project/raw_data/image_data/train_validation_test/train'
val_data_dir = '/Users/et/code/Lucia-Cordero/ReefSight-Project/raw_data/image_data/train_validation_test/val'
test_data_dir = '/Users/et/code/Lucia-Cordero/ReefSight-Project/raw_data/image_data/train_validation_test/test'

# Additionally, define path to save model
model_path = '/Users/et/code/Lucia-Cordero/ReefSight-Project/models'

# %% [markdown]
# # Baseline model

# %%
# Load data using image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

batch_size = 16
seed = 42
image_size = (224, 224)

# Load datasets
train_ds = image_dataset_from_directory(
    train_data_dir,
    labels="inferred",
    label_mode="binary",
    seed=seed,
    image_size=image_size,
    batch_size=batch_size
)

val_ds = image_dataset_from_directory(
    val_data_dir,
    labels="inferred",
    label_mode="binary",
    seed=seed,
    image_size=image_size,
    batch_size=batch_size
)

test_ds = image_dataset_from_directory(
    test_data_dir,
    labels="inferred",
    label_mode="binary",
    seed=seed,
    image_size=image_size,
    batch_size=batch_size
)

print("Class names train dataset:", train_ds.class_names)
print("Class names validation dataset:", val_ds.class_names)
print("Class names test dataset:", test_ds.class_names)
# Out:
# Found 540 files belonging to 2 classes.
# Found 179 files belonging to 2 classes.
# Found 182 files belonging to 2 classes.
# Class names train dataset: ['Bleached', 'Unbleached']
# Class names validation dataset: ['Bleached', 'Unbleached']
# Class names test dataset: ['Bleached', 'Unbleached']

# %%
# Built and compile baseline CNN model

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras import layers, optimizers, Input, regularizers

image_size = (224, 224)
input_shape = image_size + (3,)
num_classes = 2
learning_rate = 0.003

def create_baseline_cnn(input_shape, num_classes=2, learning_rate=0.001):

    # Build the model
    model = Sequential()

    # Normalize pixel values to [0,1] inside the model so saved model includes preprocessing
    model.add(layers.Rescaling(1./255, input_shape=input_shape))

    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding="same"))
    model.add(layers.MaxPooling2D(2, 2))

    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding="same"))
    model.add(layers.MaxPooling2D(2, 2))

    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding="same"))
    model.add(layers.MaxPooling2D(2, 2))
    model.add(layers.Flatten())

    model.add(layers.Dense(64, activation="relu"))
    model.add(layers.Dropout(0.5))

    model.add(layers.Dense(1, activation='sigmoid'))

    # Compile the model
    adam = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])

    return model

baseline_model = create_baseline_cnn(input_shape, num_classes, learning_rate)
baseline_model.summary()
# Out:
# /Users/et/.pyenv/versions/3.10.6/envs/ReefSight-Project/lib/python3.10/site-packages/keras/src/layers/preprocessing/data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     6,422,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,515,905 (24.86 MB)
#  Trainable params: 6,515,905 (24.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the baseline model using tf.data `train_ds` and `val_ds`

import os

# Configure callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                     patience=10,
                                     restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint(os.path.join(model_path, 'baseline_image_model.keras'),
                                       monitor='val_accuracy',
                                       save_best_only=True), # What does ModelCheckpoint do?
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy',
                                         factor=0.5,
                                         patience=2,
                                         verbose=1), # What does ReduceLROnPlateau do?
]

# Train using datasets
epochs = 1000

history = baseline_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=callbacks,
)
# Out:
# Epoch 1/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 172ms/step - accuracy: 0.5241 - loss: 1.0956 - val_accuracy: 0.5587 - val_loss: 0.6915 - learning_rate: 0.0030
# Epoch 2/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - accuracy: 0.5574 - loss: 0.6917 - val_accuracy: 0.5307 - val_loss: 0.6914 - learning_rate: 0.0030
# Epoch 3/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.5605 - loss: 0.6899
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.001500000013038516.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 165ms/step - accuracy: 0.5315 - loss: 0.6921 - val_accuracy: 0.5307 - val_loss: 0.6911 - learning_rate: 0.0030
# Epoch 4/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 166ms/step - accuracy: 0.5611 - loss: 0.6875 - val_accuracy: 0.5810 - val_loss: 0.6497 - learning_rate: 0.0015
# Epoch 5/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - accuracy: 0.6296 - loss: 0.6743 - val_accuracy: 0.7207 - val_loss: 0.6017 - learning_rate: 0.0015
# Epoch 6/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - accuracy: 0.6556 - loss: 0.6604 - val_accuracy: 0.7430 - val_loss: 0.5954 - learning_rate: 0.0015
# Epoch 7/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 172ms/step - accuracy: 0.6963 - loss: 0.6389 - val_accuracy: 0.7151 - val_loss: 0.5778 - learning_rate: 0.0015
# Epoch 8/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.6651 - loss: 0.6433
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.000750000006519258.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - accuracy: 0.6944 - loss: 0.6246 - val_accuracy: 0.7207 - val_loss: 0.5720 - learning_rate: 0.0015
# Epoch 9/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - accuracy: 0.6889 - loss: 0.6103 - val_accuracy: 0.7207 - val_loss: 0.5745 - learning_rate: 7.5000e-04
# Epoch 10/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.7016 - loss: 0.5972
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.000375000003259629.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 165ms/step - accuracy: 0.7222 - loss: 0.5824 - val_accuracy: 0.7374 - val_loss: 0.5482 - learning_rate: 7.5000e-04
# Epoch 11/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.7333 - loss: 0.5649 - val_accuracy: 0.7542 - val_loss: 0.5270 - learning_rate: 3.7500e-04
# Epoch 12/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 166ms/step - accuracy: 0.7222 - loss: 0.5343 - val_accuracy: 0.7374 - val_loss: 0.5097 - learning_rate: 3.7500e-04
# Epoch 13/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.7315 - loss: 0.5375 - val_accuracy: 0.7598 - val_loss: 0.5074 - learning_rate: 3.7500e-04
# Epoch 14/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - accuracy: 0.7481 - loss: 0.5163 - val_accuracy: 0.7598 - val_loss: 0.5019 - learning_rate: 3.7500e-04
# Epoch 15/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - accuracy: 0.7389 - loss: 0.5160 - val_accuracy: 0.7765 - val_loss: 0.4956 - learning_rate: 3.7500e-04
# Epoch 16/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 172ms/step - accuracy: 0.7407 - loss: 0.5087 - val_accuracy: 0.7542 - val_loss: 0.5044 - learning_rate: 3.7500e-04
# Epoch 17/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.7302 - loss: 0.4979
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001875000016298145.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - accuracy: 0.7463 - loss: 0.4890 - val_accuracy: 0.7765 - val_loss: 0.4909 - learning_rate: 3.7500e-04
# Epoch 18/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - accuracy: 0.7741 - loss: 0.4694 - val_accuracy: 0.7821 - val_loss: 0.4890 - learning_rate: 1.8750e-04
# Epoch 19/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.7685 - loss: 0.4620 - val_accuracy: 0.7821 - val_loss: 0.4812 - learning_rate: 1.8750e-04
# Epoch 20/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.7444 - loss: 0.4632 - val_accuracy: 0.7877 - val_loss: 0.4862 - learning_rate: 1.8750e-04
# Epoch 21/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - accuracy: 0.7704 - loss: 0.4476 - val_accuracy: 0.7989 - val_loss: 0.4790 - learning_rate: 1.8750e-04
# Epoch 22/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - accuracy: 0.7722 - loss: 0.4331 - val_accuracy: 0.7821 - val_loss: 0.4907 - learning_rate: 1.8750e-04
# Epoch 23/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.7597 - loss: 0.4548
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.375000081490725e-05.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.7759 - loss: 0.4328 - val_accuracy: 0.7877 - val_loss: 0.4772 - learning_rate: 1.8750e-04
# Epoch 24/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - accuracy: 0.7889 - loss: 0.4183 - val_accuracy: 0.7821 - val_loss: 0.4878 - learning_rate: 9.3750e-05
# Epoch 25/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.7839 - loss: 0.4276
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.6875000407453626e-05.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 172ms/step - accuracy: 0.7685 - loss: 0.4333 - val_accuracy: 0.7877 - val_loss: 0.4739 - learning_rate: 9.3750e-05
# Epoch 26/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 172ms/step - accuracy: 0.7944 - loss: 0.4038 - val_accuracy: 0.8045 - val_loss: 0.4743 - learning_rate: 4.6875e-05
# Epoch 27/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.7870 - loss: 0.4007 - val_accuracy: 0.7989 - val_loss: 0.4728 - learning_rate: 4.6875e-05
# Epoch 28/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.7789 - loss: 0.4197
# Epoch 28: ReduceLROnPlateau reducing learning rate to 2.3437500203726813e-05.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - accuracy: 0.7852 - loss: 0.4093 - val_accuracy: 0.7933 - val_loss: 0.4734 - learning_rate: 4.6875e-05
# Epoch 29/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.7796 - loss: 0.4008 - val_accuracy: 0.7989 - val_loss: 0.4743 - learning_rate: 2.3438e-05
# Epoch 30/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7865 - loss: 0.4080
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.1718750101863407e-05.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.7870 - loss: 0.3978 - val_accuracy: 0.7989 - val_loss: 0.4745 - learning_rate: 2.3438e-05
# Epoch 31/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.7907 - loss: 0.3988 - val_accuracy: 0.7989 - val_loss: 0.4746 - learning_rate: 1.1719e-05
# Epoch 32/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.7811 - loss: 0.3977
# Epoch 32: ReduceLROnPlateau reducing learning rate to 5.859375050931703e-06.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - accuracy: 0.7944 - loss: 0.3853 - val_accuracy: 0.7989 - val_loss: 0.4752 - learning_rate: 1.1719e-05
# Epoch 33/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - accuracy: 0.7870 - loss: 0.3937 - val_accuracy: 0.7989 - val_loss: 0.4750 - learning_rate: 5.8594e-06
# Epoch 34/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.7932 - loss: 0.3897
# Epoch 34: ReduceLROnPlateau reducing learning rate to 2.9296875254658516e-06.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - accuracy: 0.7944 - loss: 0.3880 - val_accuracy: 0.7989 - val_loss: 0.4748 - learning_rate: 5.8594e-06
# Epoch 35/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.8019 - loss: 0.3900 - val_accuracy: 0.7989 - val_loss: 0.4746 - learning_rate: 2.9297e-06
# Epoch 36/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8050 - loss: 0.3795
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.4648437627329258e-06.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - accuracy: 0.7889 - loss: 0.3888 - val_accuracy: 0.7933 - val_loss: 0.4745 - learning_rate: 2.9297e-06

# %%
import matplotlib.pyplot as plt

# Plot training history

def plot_history(history):
    fig, ax = plt.subplots(1, 2, figsize=(15,5))
    ax[0].set_title('loss')
    ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
    ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax[1].set_title('accuracy')
    ax[1].plot(history.epoch, history.history["accuracy"], label="Train acc")
    ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation acc")
    ax[0].legend()
    ax[1].legend()

plot_history(history)

# %%
# Evaluate the model on the val dataset

test_loss, test_accuracy = baseline_model.evaluate(val_ds)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")


# Evaluate the model on the test dataset

test_loss, test_accuracy = baseline_model.evaluate(test_ds)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8045 - loss: 0.4743
# Test Loss: 0.47428736090660095
# Test Accuracy: 0.8044692873954773
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7582 - loss: 0.4539
# Test Loss: 0.4539041519165039
# Test Accuracy: 0.7582417726516724

# %%
# Plot confusion matrix

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_true = []
y_pred = []

# Iterate through the test dataset to collect predictions
for images, labels in test_ds:
    y_true.extend(labels)  # Assuming labels are already in a format compatible with y_true
    predictions = baseline_model.predict(images)
    # For binary classification, use a threshold of 0.5 to determine class
    predicted_class = (predictions > 0.5).astype(int)  # Convert probabilities to class labels
    y_pred.extend(predicted_class)

# Create confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_ds.class_names)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2025-12-14 12:08:52.837446: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# # Predict from saved model

# %%
model_loaded = tf.keras.models.load_model(os.path.join('/Users/et/code/Lucia-Cordero/ReefSight-Project/models', 'baseline_image_model.keras'))
model_loaded.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     6,422,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,547,717 (74.57 MB)
#  Trainable params: 6,515,905 (24.86 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 13,031,812 (49.71 MB)

# %% [markdown]
# # Predictions

# %%
# Make predictions on a single image from the test dataset
from tensorflow.keras.preprocessing import image
import random

# List all files in the directory
image_files_bleached = [f for f in os.listdir(test_data_dir + '/Bleached') if os.path.isfile(os.path.join(test_data_dir + '/Bleached', f))]
image_files_unbleached = [f for f in os.listdir(test_data_dir + '/Unbleached') if os.path.isfile(os.path.join(test_data_dir + '/Unbleached', f))]

# Select a random image file
random_image = random.choice(image_files_bleached)

print(f'Randomly selected image: {random_image}')

# Load the image
img_path = test_data_dir + '/Bleached/' + random_image
img = image.load_img(img_path, target_size=(224, 224))
img.convert('RGB')  # Ensure image is in RGB format
img_array = image.img_to_array(img)
#img_array /= 255.0
img_array = np.expand_dims(img_array, axis=0)

# Make prediction
predictions = model_loaded.predict(img_array)
print(f"Probability Unbleached: {predictions[0][0]}")
print(f"Probability Bleached: {1-predictions[0][0]}")

predicted_class = (predictions[0][0] >= 0.5).astype("int32")
print(f"Predicted class index: {predicted_class}")

class_names = test_ds.class_names
print(f"Class names test dataset:", test_ds.class_names)

predicted_label = class_names[predicted_class]
print(f"Predicted class: {predicted_label}")

# Visualize the image
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# Randomly selected image: 33588071250_5c474b890d_o.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Probability Unbleached: 0.7999751567840576
# Probability Bleached: 0.20002484321594238
# Predicted class index: 1
# Class names test dataset: ['Bleached', 'Unbleached']
# Predicted class: Unbleached

# %%
# Alternatively, make predictions on a batch of images from the test dataset

#Displaying predicstions vs true labels for 1 batch in test_set
for images, labels in test_ds.take(1):
    preds = model_loaded.predict(images)
    # Convert tensors to arrays
    true_labels = labels.numpy().astype(int).reshape(-1)
    pred_labels = (preds > 0.5).astype(int).reshape(-1)
    probs = preds.reshape(-1) # flattent to 1D
    break
# Map numeric labels → class names
class_names = test_ds.class_names
true_class_names = [class_names[i] for i in true_labels]
pred_class_names = [class_names[i] for i in pred_labels]
print("True classes:", true_class_names)
print("Predicted classes:", pred_class_names)


#Displaying one image with readable class names
import matplotlib.pyplot as plt
i = 11  # choose image index
pred_class_name = class_names[pred_labels[i]]
prob_unbleached = float(preds[i])
prob_bleached = 1 - prob_unbleached
plt.imshow(images[i].numpy().astype("uint8"))
plt.title(f"{pred_class_name} (prob_unbleached: {prob_unbleached:.2f}, prob_bleached: {prob_bleached:.2f})")
plt.axis("off")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# True classes: ['Unbleached', 'Bleached', 'Bleached', 'Bleached', 'Bleached', 'Unbleached', 'Bleached', 'Bleached', 'Unbleached', 'Bleached', 'Bleached', 'Bleached', 'Bleached', 'Bleached', 'Unbleached', 'Unbleached']
# Predicted classes: ['Unbleached', 'Bleached', 'Bleached', 'Bleached', 'Bleached', 'Bleached', 'Bleached', 'Bleached', 'Unbleached', 'Bleached', 'Bleached', 'Bleached', 'Bleached', 'Bleached', 'Bleached', 'Unbleached']
# /var/folders/d9/v5_06vd52pj5h82bcx8qbzbm0000gn/T/ipykernel_3319/1183402069.py:23: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   prob_unbleached = float(preds[i])
